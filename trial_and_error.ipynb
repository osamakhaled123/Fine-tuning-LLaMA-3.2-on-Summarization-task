# %%
from huggingface_hub import upload_folder, HfApi, login
from src import _config
import datasets
import os
import json
import tqdm

# %%
# train_data = datasets.load_dataset("json", data_files="jsonl_shards/train_*.jsonl")
# test_data = datasets.load_dataset("json", data_files="jsonl_shards/test_0000.jsonl")
tokenized_train_data = datasets.load_from_disk("data/cnn_train_set")
tokenized_test_data = datasets.load_from_disk("data/cnn_test_set")

# %%
tokenized_test_data
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 4596
# })

# %%
tokenized_train_data
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 114845
# })

# %%
login(token=_config.token_name)

# %%
api = HfApi()

# %%
dataset_dict = datasets.DatasetDict({"train":tokenized_train_data,
                            "test":tokenized_test_data})

# %%
dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 114845
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 4596
#     })
# })

# %%
dataset_dict.push_to_hub("osamakhaledML9/cnn_tokenized_datasets",
                         max_shard_size="500MB")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Upload 0 LFS files: 0it [00:00, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Upload 0 LFS files: 0it [00:03, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Upload 0 LFS files: 0it [00:00, ?it/s]
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Upload 0 LFS files: 0it [00:00, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/osamakhaledML9/cnn_tokenized_datasets/commit/e9e6d5f4786194247ca40e45b3eaae67d97cd267', commit_message='Upload dataset', commit_description='', oid='e9e6d5f4786194247ca40e45b3eaae67d97cd267', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/osamakhaledML9/cnn_tokenized_datasets', endpoint='https://huggingface.co', repo_type='dataset', repo_id='osamakhaledML9/cnn_tokenized_datasets'), pr_revision=None, pr_num=None)

# %%
train = datasets.load_dataset("osamakhaledML9/cnn_tokenized_datasets", split="train")
test = datasets.load_dataset("osamakhaledML9/cnn_tokenized_datasets", split="test")
# Out:
# README.md:   0%|          | 0.00/460 [00:00<?, ?B/s]
# train-00000-of-00003.parquet:   0%|          | 0.00/63.1M [00:00<?, ?B/s]
# train-00001-of-00003.parquet:   0%|          | 0.00/69.7M [00:00<?, ?B/s]
# train-00002-of-00003.parquet:   0%|          | 0.00/71.8M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/7.10M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/4596 [00:00<?, ? examples/s]

# %%
train
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 114845
# })

# %%
test
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 4596
# })

# %%
train[0]
# Out:
# {'input_ids': [128000,
#   9370,
#   5730,
#   553,
#   279,
#   2768,
#   4652,
#   512,
#   43,
#   87228,
#   11,
#   9635,
#   320,
#   36978,
#   8,
#   1198,
#   14253,
#   30427,
#   6917,
#   15469,
#   21254,
#   80556,
#   20192,
#   2680,
#   311,
#   264,
#   5068,
#   7083,
#   508,
#   3610,
#   1746,
#   3174,
#   13,
#   16,
#   3610,
#   8,
#   33415,
#   439,
#   568,
#   10800,
#   220,
#   972,
#   389,
#   7159,
#   11,
#   719,
#   568,
#   43446,
#   279,
#   3300,
#   2834,
#   956,
#   6445,
#   264,
#   13141,
#   389,
#   1461,
#   13,
#   15469,
#   21254,
#   80556,
#   439,
#   14253,
#   30427,
#   304,
#   330,
#   42398,
#   30427,
#   323,
#   279,
#   7365,
#   315,
#   279,
#   23503,
#   1,
#   2057,
#   279,
#   41698,
#   315,
#   58587,
#   3330,
#   1705,
#   2212,
#   279,
#   1917,
#   11,
#   279,
#   3995,
#   12360,
#   2795,
#   568,
#   706,
#   912,
#   6787,
#   311,
#   282,
#   1018,
#   466,
#   813,
#   8515,
#   3201,
#   389,
# ...
